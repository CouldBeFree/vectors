# %% [markdown]
# Lesson 1  https://github.com/engineersCode/EngComp4_landlinear

# %%
import numpy
# %matplotlib inline
from matplotlib import pyplot

# %%
import sys
sys.path.append('../scripts/')
from plot_helper import *

# %%
vectors = [(2, 2)]
tails = [(-3, -2), (-3, 1), (0, 0), (1, -3)]
plot_vector(vectors, tails)

# %%
vectors = [(4, 5)]
tails = [(3,3), (1, -5), (8, -3), (1, 1)]
plot_vector(vectors, tails)

# %%
a = numpy.array((-2, 1))
b = numpy.array((1, -3))
origin = numpy.array((0,0))

vectors = [a, b, a+b]
tails = [origin, a, origin]
plot_vector(vectors, tails)

# %%
c = numpy.array((3,2))
vectors = [c, 3*c]
plot_vector(vectors)

# %%
d = numpy.array((4, 7))
vectors = [d, -2*d]
plot_vector(vectors)

# %%
i = numpy.array((1,0))
j = numpy.array((0,1))
vec = 3*i + 2*j
vectors = [i, j, 3*i, 2*j, vec]
plot_vector(vectors)

# %% [markdown]
# **Linear combination** -- adding together two vectors that each scaled.
#
# **Span** -- set of all possible linear combinations

# %%
from numpy.random import randint

# %%
vectors = []
for _ in range(40):
    m = randint(-10, 10)
    n = randint(-10, 10)
    vectors.append(m*i + n*j)
plot_vector(vectors)
